# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
module_items_df = pd.read_csv('data/additional/module_items.csv')
from sklearn.dummy import DummyClassifier, DummyRegressor
import numpy as np
# Preprocessing and pipeline
from sklearn.impute import SimpleImputer
import mglearn
# train test split and cross validation
from sklearn.model_selection import cross_val_score, cross_validate, train_test_split
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.preprocessing import (
    MinMaxScaler,
    OneHotEncoder,
    OrdinalEncoder,
    StandardScaler,
)
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor

# %%
module_items_df.head()
# Out:
#                                  id  \
# 0  26503cd777cadb209a97e307a1ec3af8
# 1  fcdfbc030a9ac50c06ce4a9ebc14b729
# 2  fd315af316a5a6e8d9cab40dc39bf569
# 3  38947f69cb85333c28dbd319d307f559
# 4  ec099680e4eb97832df74a928397fbb5
#
#                                                title  position  indent  \
# 0                                       Assignment 1        14       1
# 1                                       Assignment 1         3       1
# 2                                       Assignment 2        10       1
# 3                                       Assignment 2         3       1
# 4  Discussion 9: Aligning institutional plans wit...         7       1
#
#    quiz_lti        type                         module_id page_url  published  \
# 0     False  Assignment  7e7c000c755210949c3819a0e3a3eb74      NaN       True
# 1     False  Assignment  9be3f97935920a983d9274a6c54dfbb8      NaN       True
# 2     False  Assignment  ce26f7eecd5831e66a3ac4067c3e3733      NaN       True
# 3     False  Assignment  3abc203cbf91a7e349498e9fe130eba5      NaN       True
# 4     False  Discussion  cc2bdba2e0464b8a4a08f016520a4222      NaN       True
#
#                          content_id  \
# 0  dcccda945258b1f93f8991c7c1f9e2d8
# 1  dcccda945258b1f93f8991c7c1f9e2d8
# 2  e0a7643d52f694d38361baef57479a70
# 3  e0a7643d52f694d38361baef57479a70
# 4  6f51d776df9d2b06eaf568e77ab46fee
#
#                                          module_name  module_position
# 0  Module 1: Understanding eLearning (two weeks l...                3
# 1     Module 2: eLearning readiness (two weeks long)                4
# 2  Module 3: Institutional organization and suppo...                5
# 3  Module 4: Institutional planning for eLearning...                6
# 4  Module 5: Government planning for eLearning (t...                7

# %%
pages_df = pd.read_csv('data/additional/pages.csv')
pages_df
# Out:
#                                                 title  \
# 0                                 0.1 Course overview
# 1                         0.10 UBC grading guidelines
# 2                            0.11 Academic misconduct
# 3   0.12 Accessibility, equity & diversity, netiqu...
# 4                             0.13 Learning analytics
# ..                                                ...
# 87              [wikipage] Assignment 2 Group sign up
# 88     Wikipage Assignment 2 Group Sign Up (Optional)
# 89   [wikipage] Assignment 3 Group sign up (optional)
# 90                                    Your Instructor
# 91             Your responses (eLearning terminology)
#
#                                              page_url  \
# 0                             0-dot-1-course-overview
# 1                     0-dot-10-ubc-grading-guidelines
# 2                        0-dot-11-academic-misconduct
# 3   0-dot-12-accessibility-equity-and-diversity-ne...
# 4                         0-dot-13-learning-analytics
# ..                                                ...
# 87                wikipage-assignment-2-group-sign-up
# 88       wikipage-assignment-2-group-sign-up-optional
# 89       wikipage-assignment-3-group-sign-up-optional
# 90                                    your-instructor
# 91               your-responses-elearning-terminology
#
#                                   id  published
# 0   b1d898888f6c7b3835249eafba32fda8       True
# 1   d4e9d4c9e20351932d918333d0ac5d5d       True
# 2   319770f1c152eab3ecc23afe264b2f12       True
# 3   9b956857f78a44a200aedbc13825b886       True
# 4   2d1bb7da0411ccc855e29a7455ae20f7       True
# ..                               ...        ...
# 87  972196dd128aeb62a66f5c02b897e7dd       True
# 88  9ee9a2cacefb8be58dde2a381617e0ad       True
# 89  0790ff605875f7393f9fde5c50c3eae4       True
# 90  47cc5ac28d341bcc8e175c649974a314       True
# 91  5dbb1884e151f5ac0e7e5dbbe2897ae5       True
#
# [92 rows x 4 columns]

# %%
nav_df = pd.read_csv('data/navigation_events.csv')
nav_df.columns

pd.DataFrame([nav_df.columns,[(nav_df[col].unique()) for col in nav_df.columns]]).T
# Out:
#                                        0  \
# 0                                   type
# 1                                 action
# 2                             event_time
# 3                             session_id
# 4                        membership_role
# 5                        membership_type
# 6                              event__id
# 7                            event__type
# 8                      event__actor_type
# 9                          event__action
# 10                    event__object_type
# 11                    event__object_name
# 12   event__object_extensions_asset_type
# 13  event__object_extensions_http_method
# 14                      event__eventTime
# 15                     event__edApp_type
# 16                   event__session_type
# 17                        object_id_type
# 18                 event__object_id_type
# 19                event__attachment_type
# 20                             object_id
# 21   event__object_extensions_asset_name
# 22                              actor_id
#
#                                                     1
# 0                                   [NavigationEvent]
# 1                                       [navigatedto]
# 2   [2033-03-27 03:08:48.947000+00:00, 2033-03-30 ...
# 3   [f8eac5633f79de90a77b33338b14dd8e, 90d33cac128...
# 4                 [["Learner"], ["Instructor"], Null]
# 5                                        [Membership]
# 6   [a3bd94baaa440f4793ad08bb64ed3a8f, 0f137ee4ff1...
# 7                                   [NavigationEvent]
# 8                                            [Person]
# 9                                       [NavigatedTo]
# 10  [Entity, Thread, AssignableDigitalResource, Page]
# 11                                  [attachment, nan]
# 12  [attachment, discussion_topic, assignment, wik...
# 13                                   [GET, POST, PUT]
# 14  [2033-03-27 03:08:48.947000+00:00, 2033-03-30 ...
# 15                              [SoftwareApplication]
# 16                                     [Session, nan]
# 17     [attachment, discussion, assignment, wikiPage]
# 18     [attachment, discussion, assignment, wikiPage]
# 19                          [pdf, png, nan, jpg, zip]
# 20  [0878d2f171deae54c6a81acc6ffeba20, aa6bffb0a91...
# 21  [file003.pdf, image006.png, Discussion 3: Fund...
# 22  [LEARNER_1, LEARNER_2, LEARNER_3, LEARNER_4, L...

# %%
discussion_df = pd.read_csv('data/additional/discussions.csv')
discussion_df
discussion_topic_df = pd.read_csv('data/additional/discussion_topics.csv')

discussion_df['id'] = discussion_df['discussion_topic_id']
discussion_combined_df = discussion_df.merge(discussion_topic_df)
pd.DataFrame([discussion_combined_df.columns,
              [(discussion_combined_df[col].unique()) for col in discussion_combined_df.columns]]).T
# Out:
#                                   0  \
# 0                          actor_id
# 1                   membership_role
# 2                         timestamp
# 3                           post_id
# 4                    post_parent_id
# 5            discussion_topic_title
# 6               discussion_topic_id
# 7   discussion_topic_message_length
# 8               post_message_length
# 9                    count_of_likes
# 10                               id
# 11                            title
# 12                         position
# 13        podcast_has_student_posts
# 14                  discussion_type
# 15                          lock_at
# 16                     allow_rating
# 17        discussion_subentry_count
# 18                      podcast_url
# 19                       read_state
# 20                        published
# 21                           pinned
# 22                   todo_date_date
#
#                                                     1
# 0   [INSTRUCTOR, LEARNER_3, LEARNER_11, LEARNER_10...
# 1                       [["Instructor"], ["Learner"]]
# 2   [2033-01-18 17:13:01+00:00, 2033-01-18 17:13:0...
# 3   [e29fca96e5557a20cabec778dc885345, cf6816ae103...
# 4   [1e1288fa5e19f13c45b0231e8cbedab6, cf6816ae103...
# 5   [Assignment 1 Discussion forum, Casual Area, D...
# 6   [132f3fab56d60839d727b966a76c1b1e, a475fae949c...
# 7   [367, 79, 264, 223, 1369, 546, 422, 388, 711, ...
# 8   [0, 564, 174, 226, 1566, 408, 1409, 1985, 535,...
# 9                                  [0, 2, 1, 3, 4, 7]
# 10  [132f3fab56d60839d727b966a76c1b1e, a475fae949c...
# 11  [Assignment 1 Discussion forum, Casual Area, D...
# 12                          [nan, 2.0, 5.0, 6.0, 3.0]
# 13                                            [False]
# 14                                         [threaded]
# 15                                              [nan]
# 16                                             [True]
# 17                                        [0, 35, 12]
# 18                                              [nan]
# 19                                     [read, unread]
# 20                                             [True]
# 21                                      [False, True]
# 22  [nan, 2033-01-22 20:06:09+00:00, 2033-03-26 19...

# %%
discussion_combined_df.head()
# Out:
#      actor_id membership_role                  timestamp  \
# 0  INSTRUCTOR  ["Instructor"]  2033-01-18 17:13:01+00:00
# 1  INSTRUCTOR  ["Instructor"]  2033-01-18 17:13:02+00:00
# 2   LEARNER_3     ["Learner"]  2033-01-28 06:55:40+00:00
# 3  LEARNER_11     ["Learner"]  2033-01-29 01:04:32+00:00
# 4   LEARNER_3     ["Learner"]  2033-01-29 05:54:31+00:00
#
#                             post_id                    post_parent_id  \
# 0  e29fca96e5557a20cabec778dc885345  1e1288fa5e19f13c45b0231e8cbedab6
# 1  cf6816ae103ab5e2c82d6595eb49e02e  1e1288fa5e19f13c45b0231e8cbedab6
# 2  abb6c24171f8b195cf0d050858e4ff18  cf6816ae103ab5e2c82d6595eb49e02e
# 3  a250f9cde1c58d4dba3d4f918e82a018  abb6c24171f8b195cf0d050858e4ff18
# 4  3ac8537702d3d7d8bf033d73a4491591  a250f9cde1c58d4dba3d4f918e82a018
#
#           discussion_topic_title               discussion_topic_id  \
# 0  Assignment 1 Discussion forum  132f3fab56d60839d727b966a76c1b1e
# 1  Assignment 1 Discussion forum  132f3fab56d60839d727b966a76c1b1e
# 2  Assignment 1 Discussion forum  132f3fab56d60839d727b966a76c1b1e
# 3  Assignment 1 Discussion forum  132f3fab56d60839d727b966a76c1b1e
# 4  Assignment 1 Discussion forum  132f3fab56d60839d727b966a76c1b1e
#
#    discussion_topic_message_length  post_message_length  count_of_likes  ...  \
# 0                              367                    0               0  ...
# 1                               79                    0               0  ...
# 2                               79                  564               0  ...
# 3                               79                  174               0  ...
# 4                               79                  226               0  ...
#
#   podcast_has_student_posts discussion_type  lock_at  allow_rating  \
# 0                     False        threaded      NaN          True
# 1                     False        threaded      NaN          True
# 2                     False        threaded      NaN          True
# 3                     False        threaded      NaN          True
# 4                     False        threaded      NaN          True
#
#   discussion_subentry_count  podcast_url  read_state  published  pinned  \
# 0                         0          NaN        read       True   False
# 1                         0          NaN        read       True   False
# 2                         0          NaN        read       True   False
# 3                         0          NaN        read       True   False
# 4                         0          NaN        read       True   False
#
#   todo_date_date
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 23 columns]

# %%
discussion_df
# Out:
#         actor_id membership_role                  timestamp  \
# 0     INSTRUCTOR  ["Instructor"]  2033-01-18 17:13:01+00:00
# 1     INSTRUCTOR  ["Instructor"]  2033-01-18 17:13:02+00:00
# 2      LEARNER_3     ["Learner"]  2033-01-28 06:55:40+00:00
# 3     LEARNER_11     ["Learner"]  2033-01-29 01:04:32+00:00
# 4      LEARNER_3     ["Learner"]  2033-01-29 05:54:31+00:00
# ...          ...             ...                        ...
# 1606  LEARNER_19     ["Learner"]  2033-03-23 15:59:20+00:00
# 1607  INSTRUCTOR  ["Instructor"]  2033-03-24 09:51:33+00:00
# 1608  LEARNER_14     ["Learner"]  2033-03-24 10:01:51+00:00
# 1609   LEARNER_2     ["Learner"]  2033-03-26 16:10:40+00:00
# 1610  INSTRUCTOR  ["Instructor"]  2033-03-26 16:13:06+00:00
#
#                                post_id                    post_parent_id  \
# 0     e29fca96e5557a20cabec778dc885345  1e1288fa5e19f13c45b0231e8cbedab6
# 1     cf6816ae103ab5e2c82d6595eb49e02e  1e1288fa5e19f13c45b0231e8cbedab6
# 2     abb6c24171f8b195cf0d050858e4ff18  cf6816ae103ab5e2c82d6595eb49e02e
# 3     a250f9cde1c58d4dba3d4f918e82a018  abb6c24171f8b195cf0d050858e4ff18
# 4     3ac8537702d3d7d8bf033d73a4491591  a250f9cde1c58d4dba3d4f918e82a018
# ...                                ...                               ...
# 1606  7a91b20369b9853e87f56d13600bb2a5  d6fe64dc8c4e1ede591ff45a98e7255c
# 1607  ed80eb6d2d9f9f86fec336142fb849af  d6fe64dc8c4e1ede591ff45a98e7255c
# 1608  a1210d7d04b9dc8555f53e773af18a28  d6fe64dc8c4e1ede591ff45a98e7255c
# 1609  d6d1a9d82c7fa0226e012984b81c0e41  d6fe64dc8c4e1ede591ff45a98e7255c
# 1610  87f85da1a493130f74f138560e60c81c  d6d1a9d82c7fa0226e012984b81c0e41
#
#              discussion_topic_title               discussion_topic_id  \
# 0     Assignment 1 Discussion forum  132f3fab56d60839d727b966a76c1b1e
# 1     Assignment 1 Discussion forum  132f3fab56d60839d727b966a76c1b1e
# 2     Assignment 1 Discussion forum  132f3fab56d60839d727b966a76c1b1e
# 3     Assignment 1 Discussion forum  132f3fab56d60839d727b966a76c1b1e
# 4     Assignment 1 Discussion forum  132f3fab56d60839d727b966a76c1b1e
# ...                             ...                               ...
# 1606         Q&A with Guest Speaker  3bc2d8a4ae8dfa21b926bc34599560e2
# 1607         Q&A with Guest Speaker  3bc2d8a4ae8dfa21b926bc34599560e2
# 1608         Q&A with Guest Speaker  3bc2d8a4ae8dfa21b926bc34599560e2
# 1609         Q&A with Guest Speaker  3bc2d8a4ae8dfa21b926bc34599560e2
# 1610         Q&A with Guest Speaker  3bc2d8a4ae8dfa21b926bc34599560e2
#
#       discussion_topic_message_length  post_message_length  count_of_likes  \
# 0                                 367                    0               0
# 1                                  79                    0               0
# 2                                  79                  564               0
# 3                                  79                  174               0
# 4                                  79                  226               0
# ...                               ...                  ...             ...
# 1606                              332                 1100               0
# 1607                              332                  111               0
# 1608                              332                  611               0
# 1609                              332                  237               0
# 1610                              332                   36               0
#
#                                     id
# 0     132f3fab56d60839d727b966a76c1b1e
# 1     132f3fab56d60839d727b966a76c1b1e
# 2     132f3fab56d60839d727b966a76c1b1e
# 3     132f3fab56d60839d727b966a76c1b1e
# 4     132f3fab56d60839d727b966a76c1b1e
# ...                                ...
# 1606  3bc2d8a4ae8dfa21b926bc34599560e2
# 1607  3bc2d8a4ae8dfa21b926bc34599560e2
# 1608  3bc2d8a4ae8dfa21b926bc34599560e2
# 1609  3bc2d8a4ae8dfa21b926bc34599560e2
# 1610  3bc2d8a4ae8dfa21b926bc34599560e2
#
# [1611 rows x 11 columns]

# %%
grade_df = pd.read_csv('data/additional/gradebook.csv')

# %%
grade_df['actor_id'] = grade_df['Student']
# grade_df.merge(discussion_df).groupby('Student').aggregate('mean')

df = grade_df.merge(discussion_df)

# %%
enrol_df = pd.read_csv('data/additional/enrollments.csv')
enrol_df['Student'] = enrol_df['user_id']
df = df.merge(enrol_df)


df.to_csv('data.csv')

# %%
df.columns
# Out:
# Index(['Student', 'Assignment 1 (c81f04547a95da2a7b88054ef491b7c4)',
#        'Assignment 2 (a4dc11e7e79361fc5886a9078aac66b8)',
#        'Assignment 3 (option A) (811d93ea379b5cdd5a19f1b5dbab88cd)',
#        'Assignment 3 (option B) (df8d1f1ff3f48fdc24a278b40c5f45cc)',
#        'Assignment 3 (option C) (bb971b36c1578cede00150acda89aa99)',
#        'Assignment 3 (option D) (f1ad954cd2cddda6e17f6fc225d1aa3e)',
#        'Participation grade: Formative (not included in final grade) (5965e0b0c712861d0efdd9be54572114)',
#        'Assignment 1 Current Score', 'Assignment 2 Current Score',
#        'Assignment 3 Current Score',
#        'Participation & engagement Current Score', 'Current Score', 'actor_id',
#        'membership_role', 'timestamp', 'post_id', 'post_parent_id',
#        'discussion_topic_title', 'discussion_topic_id',
#        'discussion_topic_message_length', 'post_message_length',
#        'count_of_likes', 'id', 'user_id', 'type', 'last_activity_at',
#        'last_attended_at', 'total_activity_time'],
#       dtype='object')

# %%
num_cols = ['Assignment 1 (c81f04547a95da2a7b88054ef491b7c4)',
       'Assignment 2 (a4dc11e7e79361fc5886a9078aac66b8)',
       'Assignment 3 (option A) (811d93ea379b5cdd5a19f1b5dbab88cd)',
       'Assignment 3 (option B) (df8d1f1ff3f48fdc24a278b40c5f45cc)',
       'Assignment 3 (option C) (bb971b36c1578cede00150acda89aa99)',
       'Assignment 3 (option D) (f1ad954cd2cddda6e17f6fc225d1aa3e)',
       'Participation grade: Formative (not included in final grade) (5965e0b0c712861d0efdd9be54572114)',
       'Assignment 1 Current Score', 'Assignment 2 Current Score',
       'Assignment 3 Current Score',
       'Participation & engagement Current Score', 'Current Score',]

for col in num_cols:
    df[col] = df[col].apply(float)

# %%
df['Assignment 1 (c81f04547a95da2a7b88054ef491b7c4)']
# Out:
# 0       88.0
# 1       88.0
# 2       88.0
# 3       88.0
# 4       88.0
#         ...
# 1291    73.0
# 1292    73.0
# 1293    73.0
# 1294    73.0
# 1295    73.0
# Name: Assignment 1 (c81f04547a95da2a7b88054ef491b7c4), Length: 1296, dtype: float64

# %%
df_mean = df.groupby('Student').aggregate('mean')
df_sum = df.groupby('Student').aggregate('sum')
df_count = df.groupby('Student').aggregate('count')

df_mean.to_csv('data_mean.csv')
df_sum.to_csv('data_sum.csv')

# %%
df_count.iloc[-3]
# Out:
# Assignment 1 (c81f04547a95da2a7b88054ef491b7c4)                                                    166
# Assignment 2 (a4dc11e7e79361fc5886a9078aac66b8)                                                    166
# Assignment 3 (option A) (811d93ea379b5cdd5a19f1b5dbab88cd)                                           0
# Assignment 3 (option B) (df8d1f1ff3f48fdc24a278b40c5f45cc)                                         166
# Assignment 3 (option C) (bb971b36c1578cede00150acda89aa99)                                           0
# Assignment 3 (option D) (f1ad954cd2cddda6e17f6fc225d1aa3e)                                           0
# Participation grade: Formative (not included in final grade) (5965e0b0c712861d0efdd9be54572114)    166
# Assignment 1 Current Score                                                                         166
# Assignment 2 Current Score                                                                         166
# Assignment 3 Current Score                                                                         166
# Participation & engagement Current Score                                                           166
# Current Score                                                                                      166
# actor_id                                                                                           166
# membership_role                                                                                    166
# timestamp                                                                                          166
# post_id                                                                                            166
# post_parent_id                                                                                     166
# discussion_topic_title                                                                             166
# discussion_topic_id                                                                                166
# discussion_topic_message_length                                                                    166
# post_message_length                                                                                166
# count_of_likes                                                                                     166
# id                                                                                                 166
# user_id                                                                                            166
# type                                                                                               166
# last_activity_at                                                                                   166
# last_attended_at                                                                                     0
# total_activity_time                                                                                166
# Name: LEARNER_6, dtype: int64

# %%
df_mean.head()
# Out:
#             Assignment 1 (c81f04547a95da2a7b88054ef491b7c4)  \
# Student
# LEARNER_1                                              79.0
# LEARNER_10                                             88.0
# LEARNER_11                                             90.0
# LEARNER_12                                             86.0
# LEARNER_13                                             88.0
#
#             Assignment 2 (a4dc11e7e79361fc5886a9078aac66b8)  \
# Student
# LEARNER_1                                              84.0
# LEARNER_10                                             72.0
# LEARNER_11                                             79.0
# LEARNER_12                                             87.0
# LEARNER_13                                             86.0
#
#             Assignment 3 (option A) (811d93ea379b5cdd5a19f1b5dbab88cd)  \
# Student
# LEARNER_1                                                 NaN
# LEARNER_10                                               74.0
# LEARNER_11                                                NaN
# LEARNER_12                                                NaN
# LEARNER_13                                               87.0
#
#             Assignment 3 (option B) (df8d1f1ff3f48fdc24a278b40c5f45cc)  \
# Student
# LEARNER_1                                                 NaN
# LEARNER_10                                                NaN
# LEARNER_11                                                NaN
# LEARNER_12                                                NaN
# LEARNER_13                                                NaN
#
#             Assignment 3 (option C) (bb971b36c1578cede00150acda89aa99)  \
# Student
# LEARNER_1                                                73.0
# LEARNER_10                                                NaN
# LEARNER_11                                               82.0
# LEARNER_12                                               73.0
# LEARNER_13                                                NaN
#
#             Assignment 3 (option D) (f1ad954cd2cddda6e17f6fc225d1aa3e)  \
# Student
# LEARNER_1                                                 NaN
# LEARNER_10                                                NaN
# LEARNER_11                                                NaN
# LEARNER_12                                                NaN
# LEARNER_13                                                NaN
#
#             Participation grade: Formative (not included in final grade) (5965e0b0c712861d0efdd9be54572114)  \
# Student
# LEARNER_1                                                 9.0
# LEARNER_10                                                8.5
# LEARNER_11                                                9.0
# LEARNER_12                                                8.0
# LEARNER_13                                                8.0
#
#             Assignment 1 Current Score  Assignment 2 Current Score  \
# Student
# LEARNER_1                         79.0                        84.0
# LEARNER_10                        88.0                        72.0
# LEARNER_11                        90.0                        79.0
# LEARNER_12                        86.0                        87.0
# LEARNER_13                        88.0                        86.0
#
#             Assignment 3 Current Score  \
# Student
# LEARNER_1                         73.0
# LEARNER_10                        74.0
# LEARNER_11                        82.0
# LEARNER_12                        73.0
# LEARNER_13                        87.0
#
#             Participation & engagement Current Score  Current Score  \
# Student
# LEARNER_1                                       90.0           80.9
# LEARNER_10                                      85.0           78.4
# LEARNER_11                                      90.0           84.3
# LEARNER_12                                      80.0           81.2
# LEARNER_13                                      80.0           85.5
#
#             discussion_topic_message_length  post_message_length  \
# Student
# LEARNER_1                        871.928571          2401.214286
# LEARNER_10                       851.035088          1059.263158
# LEARNER_11                       998.500000          1276.906250
# LEARNER_12                       953.600000          1141.900000
# LEARNER_13                       899.682927          1076.146341
#
#             count_of_likes  last_attended_at  total_activity_time
# Student
# LEARNER_1         0.214286               NaN             985351.0
# LEARNER_10        0.298246               NaN             421763.0
# LEARNER_11        0.156250               NaN             285214.0
# LEARNER_12        0.200000               NaN             176035.0
# LEARNER_13        0.219512               NaN             774430.0

# %%
df_sum.head()
# Out:
#             Assignment 1 (c81f04547a95da2a7b88054ef491b7c4)  \
# Student
# LEARNER_1                                            1106.0
# LEARNER_10                                           5016.0
# LEARNER_11                                           2880.0
# LEARNER_12                                           1720.0
# LEARNER_13                                           3608.0
#
#             Assignment 2 (a4dc11e7e79361fc5886a9078aac66b8)  \
# Student
# LEARNER_1                                            1176.0
# LEARNER_10                                           4104.0
# LEARNER_11                                           2528.0
# LEARNER_12                                           1740.0
# LEARNER_13                                           3526.0
#
#             Assignment 3 (option A) (811d93ea379b5cdd5a19f1b5dbab88cd)  \
# Student
# LEARNER_1                                                 0.0
# LEARNER_10                                             4218.0
# LEARNER_11                                                0.0
# LEARNER_12                                                0.0
# LEARNER_13                                             3567.0
#
#             Assignment 3 (option B) (df8d1f1ff3f48fdc24a278b40c5f45cc)  \
# Student
# LEARNER_1                                                 0.0
# LEARNER_10                                                0.0
# LEARNER_11                                                0.0
# LEARNER_12                                                0.0
# LEARNER_13                                                0.0
#
#             Assignment 3 (option C) (bb971b36c1578cede00150acda89aa99)  \
# Student
# LEARNER_1                                              1022.0
# LEARNER_10                                                0.0
# LEARNER_11                                             2624.0
# LEARNER_12                                             1460.0
# LEARNER_13                                                0.0
#
#             Assignment 3 (option D) (f1ad954cd2cddda6e17f6fc225d1aa3e)  \
# Student
# LEARNER_1                                                 0.0
# LEARNER_10                                                0.0
# LEARNER_11                                                0.0
# LEARNER_12                                                0.0
# LEARNER_13                                                0.0
#
#             Participation grade: Formative (not included in final grade) (5965e0b0c712861d0efdd9be54572114)  \
# Student
# LEARNER_1                                               126.0
# LEARNER_10                                              484.5
# LEARNER_11                                              288.0
# LEARNER_12                                              160.0
# LEARNER_13                                              328.0
#
#             Assignment 1 Current Score  Assignment 2 Current Score  \
# Student
# LEARNER_1                       1106.0                      1176.0
# LEARNER_10                      5016.0                      4104.0
# LEARNER_11                      2880.0                      2528.0
# LEARNER_12                      1720.0                      1740.0
# LEARNER_13                      3608.0                      3526.0
#
#             Assignment 3 Current Score  \
# Student
# LEARNER_1                       1022.0
# LEARNER_10                      4218.0
# LEARNER_11                      2624.0
# LEARNER_12                      1460.0
# LEARNER_13                      3567.0
#
#             Participation & engagement Current Score  Current Score  \
# Student
# LEARNER_1                                     1260.0         1132.6
# LEARNER_10                                    4845.0         4468.8
# LEARNER_11                                    2880.0         2697.6
# LEARNER_12                                    1600.0         1624.0
# LEARNER_13                                    3280.0         3505.5
#
#             discussion_topic_message_length  post_message_length  \
# Student
# LEARNER_1                             12207                33617
# LEARNER_10                            48509                60378
# LEARNER_11                            31952                40861
# LEARNER_12                            19072                22838
# LEARNER_13                            36887                44122
#
#             count_of_likes  last_attended_at  total_activity_time
# Student
# LEARNER_1                3               0.0             13794914
# LEARNER_10              17               0.0             24040491
# LEARNER_11               5               0.0              9126848
# LEARNER_12               4               0.0              3520700
# LEARNER_13               9               0.0             31751630

# %%
canvas_df = pd.concat([df_mean[['Participation & engagement Current Score','Current Score',
                                'count_of_likes','total_activity_time']], 
                       df_sum[['discussion_topic_message_length','post_message_length']],
                      df_count[['last_activity_at']]],axis =1)

canvas_df['answer_count'] =  canvas_df['last_activity_at']
canvas_df = canvas_df.drop(['last_activity_at'],axis = 1)

# %%
# canvas_df.to_csv('canvas_df.csv')

# %%
# for col in canvas_df.columns:
#     canvas_df[col].hist()
#     plt.show()

# %%
train_df, test_df = train_test_split(canvas_df, test_size=0.2, random_state=123)

train_df.head()
# Out:
#             Participation & engagement Current Score  Current Score  \
# Student
# LEARNER_16                                     100.0           82.0
# LEARNER_33                                      40.0           72.1
# LEARNER_20                                      55.0           69.7
# LEARNER_2                                       60.0           84.6
# LEARNER_25                                      90.0           87.3
#
#             count_of_likes  total_activity_time  \
# Student
# LEARNER_16        0.196078             586198.0
# LEARNER_33        0.000000             547149.0
# LEARNER_20        0.045455             201541.0
# LEARNER_2         0.290323             152876.0
# LEARNER_25        0.205128             110669.0
#
#             discussion_topic_message_length  post_message_length  answer_count
# Student
# LEARNER_16                            45110                87921            51
# LEARNER_33                             9085                 7047             9
# LEARNER_20                            21776                20719            22
# LEARNER_2                             22443                32704            31
# LEARNER_25                            34233                25090            39

# %%
X_train = train_df.drop(['Current Score'], axis=1)
X_test = test_df.drop(['Current Score'], axis=1)
y_train = train_df['Current Score']
y_test = test_df['Current Score']

# %%
dummy = DummyRegressor()
dummy.fit(X_train, y_train)
dummy.score(X_test, y_test)
# Out:
# -0.04886244503632664

# %%
svr = SVR(kernel='linear')

pipe = make_pipeline(StandardScaler(), svr)
pipe.fit(X_train, y_train)
pipe.score(X_test,y_test)
# Out:
# 0.3512155037729606

# %%
pd.DataFrame(pipe.predict(X_train),y_train)
# Out:
#                        0
# Current Score
# 82.0           82.099938
# 72.1           71.999660
# 69.7           74.776971
# 84.6           77.977429
# 87.3           84.272649
# 85.5           81.570958
# 81.2           81.462060
# 82.3           77.606390
# 89.0           83.672564
# 73.0           74.191207
# 89.2           87.315974
# 81.3           81.399939
# 69.7           73.584925
# 86.4           86.499860
# 87.3           87.400604
# 80.9           83.385389
# 78.4           82.547281
# 77.9           80.633960
# 79.1           81.528548
# 85.2           81.855938
# 85.7           81.604787
# 87.5           84.536720
# 76.2           76.180459
# 83.6           83.648316
# 82.9           83.861354
# 84.3           82.255521

# %%
pd.DataFrame(pipe.predict(X_test),y_test)
# Out:
#                        0
# Current Score
# 65.7           72.872962
# 70.9           74.479592
# 84.4           72.458937
# 88.0           80.992390
# 78.3           79.749131
# 92.2           83.516217
# 78.5           75.942844

# %%
lr = LinearRegression()

pipe = make_pipeline(StandardScaler(), lr)
pipe.fit(X_train, y_train)
pipe.score(X_test,y_test)
# Out:
# 0.3377115893215409

# %%
pd.DataFrame(pipe.predict(X_test),y_test)
# Out:
#                        0
# Current Score
# 65.7           73.436971
# 70.9           73.315744
# 84.4           69.019655
# 88.0           82.609518
# 78.3           76.800560
# 92.2           90.378952
# 78.5           75.304511

# %%
lr.coef_
# Out:
# array([ 4.69445741,  1.01823222,  0.61822843, -6.81818202, -2.95181991,
#         8.51483447])

# %%
X_train.columns
# Out:
# Index(['Participation & engagement Current Score', 'count_of_likes',
#        'total_activity_time', 'discussion_topic_message_length',
#        'post_message_length', 'answer_count'],
#       dtype='object')

# %%
res = []
for i in range(50):
    tree = DecisionTreeRegressor(max_depth=i+1)

    pipe = make_pipeline(StandardScaler(), tree)
    pipe.fit(X_train, y_train)
    print(pipe.score(X_test,y_test), i+1)
    res.append(pipe.score(X_test,y_test))
    
plt.plot(range(50), res)
# Out:
# 0.35576887345735164 1
# 0.4934825393331451 2
# 0.35521298427998194 3
# 0.26341908808280334 4
# 0.4510358649904056 5
# 0.3641735359967445 6
# 0.3354495594905801 7
# 0.13152586357292406 8
# 0.018582628227495124 9
# 0.07346094295184957 10
# 0.5186889392882076 11
# 0.45608262822749557 12
# 0.3493981158408943 13
# 0.061687674459176445 14
# 0.4068715108164699 15
# 0.4726644277739017 16
# 0.45610170969993113 17
# 0.39246499912770483 18
# 0.5352516573621782 19
# 0.3980367890788564 20
# 0.15106529134682523 21
# 0.3599692515701335 22
# 0.39246499912770483 23
# 0.3824472260990939 24
# 0.41536276605024514 25
# 0.1705856376482905 26
# -0.005708086182833139 27
# 0.46304736566643523 28
# 0.4491369722609917 29
# 0.46304736566643523 30
# 0.2686644059665052 31
# 0.5186889392882076 32
# 0.30077852407536754 33
# 0.5296798674110268 34
# 0.06788915300069798 35
# 0.3689375436147948 36
# 0.41536276605024514 37
# 0.3768754361479424 38
# 0.5088047365666443 39
# 0.32430597958827767 40
# 0.3834967070830436 41
# 0.3187341896371261 42
# -0.0058416564898806644 43
# 0.04993348743893922 44
# 0.45610170969993113 45
# 0.32430597958827767 46
# -0.07943889567341178 47
# 0.3354495594905801 48
# 0.3768754361479424 49
# -0.02936911200279102 50

# %%
ridge = Ridge(alpha=1)

pipe = make_pipeline(StandardScaler(), ridge)
pipe.fit(X_train, y_train)
pipe.score(X_train, y_train)
# Out:
# 0.731989761181396

# %%
pipe['ridge'].coef_
# Out:
# array([ 4.16411239,  1.32559565,  0.44398997, -0.700075  , -2.07163397,
#         1.9361241 ])

# %%
X_train.columns
# Out:
# Index(['Participation & engagement Current Score', 'count_of_likes',
#        'total_activity_time', 'discussion_topic_message_length',
#        'post_message_length', 'answer_count'],
#       dtype='object')

# %%
res = []
for i in range(50):
    tree = DecisionTreeRegressor(max_depth=i+1)

    pipe = make_pipeline(MinMaxScaler(), tree)
    pipe.fit(X_train, y_train)
    res.append(pipe.score(X_test,y_test))
    
plt.plot(range(50), res)

# %%
pipe_svm = make_pipeline(StandardScaler(), SVR(kernel = 'linear'))

param_grid = {
    "svr__gamma": [0.001, 0.01, 0.1, 1.0, 10, 100],
    "svr__C": [0.001, 0.01, 0.1, 1.0, 10, 100],
}

grid_search = GridSearchCV(
    pipe_svm, param_grid, cv=5, n_jobs=-1, return_train_score=True
)

# %%
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('svr', SVR(kernel='linear'))]),
#              n_jobs=-1,
#              param_grid={'svr__C': [0.001, 0.01, 0.1, 1.0, 10, 100],
#                          'svr__gamma': [0.001, 0.01, 0.1, 1.0, 10, 100]},
#              return_train_score=True)

# %%
grid_search.best_score_
# Out:
# 0.37557520726641813

# %%
def display_heatmap(param_grid, pipe, X_train, y_train):
    grid_search = GridSearchCV(
        pipe, param_grid, cv=5, n_jobs=-1, return_train_score=True
    )
    grid_search.fit(X_train, y_train)
    results = pd.DataFrame(grid_search.cv_results_)
    scores = np.array(results.mean_test_score).reshape(6, 6)

    # plot the mean cross-validation scores
    mglearn.tools.heatmap(
        scores,
        xlabel="gamma",
        xticklabels=param_grid["svr__gamma"],
        ylabel="C",
        yticklabels=param_grid["svr__C"],
        cmap="viridis",
    );
param_grid1 = {
    "svr__gamma": 10.0**np.arange(-3, 3, 1), 
    "svr__C": 10.0**np.arange(-3, 3, 1)
}
display_heatmap(param_grid1, pipe_svm, X_train, y_train)
